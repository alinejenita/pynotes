# %%
import os

os.mkdir("pics")
print("Created")
# Out:
# ---------------------------------------------------------------------------
# FileExistsError                           Traceback (most recent call last)
# Cell In[2], line 3
#       1 import os
# ----> 3 os.mkdir("pics")
#       4 print("Created")
#
# FileExistsError: [Errno 17] File exists: 'pics'

# %%
import os
os.remove("pics")
# Out:
# ---------------------------------------------------------------------------
# PermissionError                           Traceback (most recent call last)
# Cell In[3], line 2
#       1 import os
# ----> 2 os.remove("pics")
#
# PermissionError: [Errno 1] Operation not permitted: 'pics'
