# %%
import os

current_path = os.getcwd()
print("Current Working Directory:", current_path)
# Out:
# Current Working Directory: /Users/jenny/kact/pynotes/notebooks/daily_learning

# %%
import os

print("Before:", os.getcwd())

os.chdir("/Users/jenny/Documents")

print("After:", os.getcwd())
# Out:
# Before: /Users/jenny/kact/pynotes/notebooks/daily_learning
# After: /Users/jenny/Documents

# %%
import os

print("Before:", os.getcwd())

os.chdir("/Users/jenny/Documents")

print("After:", os.getcwd())
